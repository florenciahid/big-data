# %%
# imports y datos
import matplotlib.pyplot as plt 
import numpy as np


arts = ['PANTALÓN', 'REMERA', 'BLUSA', 'CAMISA', 'POLLERA', 'ABRIGO']
stock = [1524, 2684, 800, 1756, 1008, 3521]

plt.bar( arts , stock )
plt.show()

# %%
# COLORES Y TAMAÑO
plt.bar( arts , stock , width=0.7 , color=["red" , "blue" , "green" , "yellow" , "violet" , "pink"] )
plt.show()

# %%
# cambiar nombre de las variables en el eje x con xticks y rotation
arts_2 = ['PANTALÓN', 'REMERA', 'BLUSA', 'CAMISA', 'POLLERA', 'ABRIGO' , 'PANTALÓN2', 'REMERA2', 'BLUSA2', 'CAMISA2', 'POLLERA2', 'ABRIGO2']
stock_2 = [1524, 2684, 800, 1756, 1008, 3521 ,1524, 2684, 800, 1756, 1008, 3521]

plt.bar( arts_2 , stock_2 )
plt.xticks(rotation=45)
plt.show()

# Rotation modifica la rotacion del texto de las gráficas (rotacion de los labels)

# %%
# barh : Es el gráfico de barras horizontal 

plt.barh(arts , stock)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e9ab2ce1-90b4-4ae6-90f4-beb0ff568079' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
